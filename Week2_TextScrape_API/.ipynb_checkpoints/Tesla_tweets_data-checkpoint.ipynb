# %%
api_key = 'zw3115BQLJsWmbuvdatHz6VPx'
api_secret = 'gegWaJTpscJEA2ZJ30Fb4rPh7UchPcVt3xtNn8ErR1z69gflH6'
access_token = '77886913-cu9c0MIGtbeG051Qy83UtD34fiU9zgOkpgnNqMqrk'
access_secret = 'Zh1fMWF5K9Wtkhr8tKDsfCKzP5H9j60cnaRGoTpPLJeFD'

# %%
import tweepy #package we will use to interact with the API.
import pandas as pd

# %%
#Authorization

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
#Print to the console the tweets from your timeline
content_list = []
time_list = []
favorite_list = []
retweet_list = []
for i in range(0,165):
    public_tweets = api.user_timeline('elonmusk', page = i)
    for tweet in public_tweets:
        content_list.append(tweet.text)
        time_list.append(tweet.created_at)
        retweet_list.append(tweet.retweet_count)
        favorite_list.append(tweet.favorite_count)

# %%
time_list[len(time_list) - 1]
# Out:
# datetime.datetime(2015, 9, 2, 2, 24, 26)

# %%
import nltk
import gensim
from gensim.utils import tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import re

stop_words = set(stopwords.words('english'))
# set of punctuation 
punctuation = set(string.punctuation)

# stemmer object
stemmer = PorterStemmer()

from nltk.tokenize import RegexpTokenizer


def clean(doc):
    # Remove stop words
    name_free = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|rt","",doc.lower()).split())
    
    stop_free = ' '.join([term for term in name_free.split() if term not in stop_words])
    
    # Remove punctuation
    punc_free = ''.join(term for term in stop_free if term not in punctuation)
    
    stemmed = ' '.join(stemmer.stem(word) for word in punc_free.split())
    
    return stemmed

# clean every document in the corpus

clean_content_list = [clean(doc).split() for doc in content_list]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/garrett/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from afinn import Afinn

# make an afinn object
afinn = Afinn()
afinn_list = []
# get sentiment for each document in the corpus 
# (unclean corpus because the clean one has some words the algorithm won't recognize)
for i in content_list:
    afinn_list.append(afinn.score(i))

# %%
all_words = []
for doc in clean_content_list:
    all_words += doc

word_frequencies = nltk.FreqDist(all_words)
word_frequencies.most_common(20)
# Out:
# [('tesla', 313),
#  ('amp', 255),
#  ('model', 218),
#  ('car', 167),
#  ('launch', 134),
#  ('like', 131),
#  ('ye', 128),
#  ('good', 126),
#  ('falcon', 126),
#  ('3', 124),
#  ('first', 105),
#  ('next', 97),
#  ('land', 95),
#  ('go', 94),
#  ('need', 90),
#  ('one', 87),
#  ('work', 87),
#  ('rocket', 85),
#  ('year', 83),
#  ('get', 81)]

# %%
tesla = pd.DataFrame({'content':clean_content_list,'time':time_list, 'retweets':retweet_list,'favorites':favorite_list, 'afinn score':afinn_list})

# %%
tesla
# Out:
#       afinn score                                            content  \
# 0             0.0                               [uk, mid, 2019, rhd]
# 1             8.0                       [sound, like, fun, adventur]
# 2             2.0  [uk, take, aero, ins, standard, wheel, amp, lo...
# 3             9.0  [model, 3, second, best, world, model, sx, sti...
# 4             2.0  [filter, bacteria, virus, spore, pollen, amp, ...
# 5             0.0  [model, amp, x, also, acid, ga, filter, alkali...
# 6             0.0  [open, door, social, media, user, come, behind...
# 7             4.0  [cool, tesla, sx, hospit, oper, room, air, qua...
# 8             0.0                                                 []
# 9             0.0               [berlin, wurst, hat, meisten, curri]
# 10            0.0  [ich, habe, der, universitt, ein, semest, deut...
# 11            0.0                                         [natrlich]
# 12            0.0                                          [definit]
# 13            3.0            [best, analysi, model, 3, date, german]
# 14            0.0                                   [finder, keeper]
# 15            0.0                                          [pravduh]
# 16            0.0                                               [hi]
# 17            0.0  [lot, model, 3, deliveri, today, toronto, tomo...
# 18           -1.0  [gfischer, tri, adjust, tire, pressur, ask, te...
# 19           -4.0                                       [hell, week]
# 20            0.0                               [uk, mid, 2019, rhd]
# 21            8.0                       [sound, like, fun, adventur]
# 22            2.0  [uk, take, aero, ins, standard, wheel, amp, lo...
# 23            9.0  [model, 3, second, best, world, model, sx, sti...
# 24            2.0  [filter, bacteria, virus, spore, pollen, amp, ...
# 25            0.0  [model, amp, x, also, acid, ga, filter, alkali...
# 26            0.0  [open, door, social, media, user, come, behind...
# 27            4.0  [cool, tesla, sx, hospit, oper, room, air, qua...
# 28            0.0                                                 []
# 29            0.0               [berlin, wurst, hat, meisten, curri]
# ...           ...                                                ...
# 3223          0.0  [tesla, model, x, final, here, stuff, didnt, a...
# 3224          4.0   [tesla, model, x, suv, final, wonder, wed, hope]
# 3225          0.0                                 [california, time]
# 3226          0.0  [model, x, launch, webcast, live, today, 8pm, ...
# 3227          2.0  [water, strong, evid, liquid, water, flow, pre...
# 3228          3.0  [great, discuss, solarbatteri, empow, rural, c...
# 3229          2.0               [china, show, commit, climat, chang]
# 3230         -2.0  [week, static, fire, first, stage, upgrad, fal...
# 3231          3.0  [dinner, old, belgian, ironmongeri, best, menu...
# 3232          6.0                                      [super, good]
# 3233          0.0                         [midnight, dinner, berlin]
# 3234          0.0  [casey, driven, 500, mile, tesla, model, 85d, ...
# 3235          0.0                                      [dragon, mar]
# 3236          1.0  [expend, mode, falcon, heavi, send, fulli, loa...
# 3237          5.0  [dragon, 2, design, land, surfac, liquid, soli...
# 3238          0.0  [research, propos, use, falcondragon, mar, sam...
# 3239          0.0  [snowpack, sierra, nevada, hit, 500year, low, ...
# 3240          2.0  [new, model, evolut, intellig, life, suggest, ...
# 3241          2.0                                            [thank]
# 3242          0.0               [btw, say, nuke, mar, layin, option]
# 3243          0.0  [crew, paner, unveil, interior, crew, dragon, ...
# 3244          0.0  [first, look, interior, crew, dragon, nextgene...
# 3245          0.0  [first, product, car, hand, sept, 29, fremont,...
# 3246          0.0                                          [definit]
# 3247          3.0  [lithium, deal, exclus, amp, mani, conting, pr...
# 3248          0.0         [35k, price, unveil, march, preorder, sta]
# 3249          0.0  [model, 3, smaller, lower, cost, sedan, sta, p...
# 3250          3.0  [option, model, x, 5k, due, greater, size, amp...
# 3251          0.0  [pad, 39a, futur, home, crew, launch, falcon, ...
# 3252          3.0       [test, drive, new, tesla, dealer, dan, love]
#
#       favorites  retweets                time
# 0           136        11 2018-06-01 08:29:40
# 1           141        11 2018-06-01 08:25:09
# 2           139         6 2018-06-01 08:23:54
# 3          1025        43 2018-06-01 02:47:53
# 4         13507      1408 2018-06-01 02:45:30
# 5          3436       396 2018-06-01 02:41:22
# 6             0      1208 2018-06-01 02:14:23
# 7         36499      5062 2018-06-01 02:13:19
# 8         34973      3655 2018-06-01 01:14:52
# 9          1073       234 2018-05-31 20:24:45
# 10         2152       280 2018-05-31 20:18:58
# 11         1612       118 2018-05-31 19:39:57
# 12         1048        66 2018-05-31 19:37:32
# 13         9100       982 2018-05-31 19:29:57
# 14        45496      4012 2018-05-31 17:48:55
# 15         5116       448 2018-05-31 17:17:06
# 16        42966      2557 2018-05-31 14:41:20
# 17            0       860 2018-05-31 07:53:01
# 18          437        10 2018-05-31 05:18:53
# 19       157447     26698 2018-05-31 04:18:00
# 20          136        11 2018-06-01 08:29:40
# 21          141        11 2018-06-01 08:25:09
# 22          139         6 2018-06-01 08:23:54
# 23         1025        43 2018-06-01 02:47:53
# 24        13507      1408 2018-06-01 02:45:30
# 25         3436       396 2018-06-01 02:41:22
# 26            0      1208 2018-06-01 02:14:23
# 27        36499      5062 2018-06-01 02:13:19
# 28        34973      3655 2018-06-01 01:14:52
# 29         1073       234 2018-05-31 20:24:45
# ...         ...       ...                 ...
# 3223          0       566 2015-09-30 07:46:33
# 3224          0      1394 2015-09-30 07:44:30
# 3225        719       178 2015-09-29 07:43:37
# 3226       5097      3838 2015-09-29 07:39:41
# 3227          0     42457 2015-09-28 16:12:34
# 3228       1973      1739 2015-09-27 01:02:35
# 3229          0       407 2015-09-26 05:38:34
# 3230          0       642 2015-09-25 08:53:39
# 3231       1819       445 2015-09-25 00:44:09
# 3232        296        39 2015-09-23 22:31:41
# 3233       3409       855 2015-09-23 22:12:49
# 3234          0       317 2015-09-16 16:44:58
# 3235          0      2440 2015-09-15 01:41:54
# 3236       3290      1640 2015-09-14 21:35:57
# 3237       3300      1456 2015-09-14 21:26:37
# 3238       2071      1298 2015-09-14 21:24:22
# 3239          0      2104 2015-09-14 16:13:49
# 3240       2360      1283 2015-09-13 07:22:13
# 3241        861       136 2015-09-12 20:46:26
# 3242       7097      4185 2015-09-12 19:07:49
# 3243          0      1416 2015-09-11 00:24:33
# 3244          0      1325 2015-09-11 00:24:27
# 3245       1736       697 2015-09-02 20:59:53
# 3246         79        12 2015-09-02 20:57:45
# 3247        100        51 2015-09-02 20:39:18
# 3248       3814      2566 2015-09-02 20:25:26
# 3249       4899      4030 2015-09-02 20:22:20
# 3250       1620       701 2015-09-02 20:17:47
# 3251          0      1055 2015-09-02 06:30:41
# 3252          0      1094 2015-09-02 02:24:26
#
# [3253 rows x 5 columns]

# %%
#from datetime import datetime
#tesla_index = tesla.groupby(tesla.time.dt.year).mean()

# %%
tesla
# Out:
#       afinn score                                            content  \
# 0             0.0                               [uk, mid, 2019, rhd]
# 1             8.0                       [sound, like, fun, adventur]
# 2             2.0  [uk, take, aero, ins, standard, wheel, amp, lo...
# 3             9.0  [model, 3, second, best, world, model, sx, sti...
# 4             2.0  [filter, bacteria, virus, spore, pollen, amp, ...
# 5             0.0  [model, amp, x, also, acid, ga, filter, alkali...
# 6             0.0  [open, door, social, media, user, come, behind...
# 7             4.0  [cool, tesla, sx, hospit, oper, room, air, qua...
# 8             0.0                                                 []
# 9             0.0               [berlin, wurst, hat, meisten, curri]
# 10            0.0  [ich, habe, der, universitt, ein, semest, deut...
# 11            0.0                                         [natrlich]
# 12            0.0                                          [definit]
# 13            3.0            [best, analysi, model, 3, date, german]
# 14            0.0                                   [finder, keeper]
# 15            0.0                                          [pravduh]
# 16            0.0                                               [hi]
# 17            0.0  [lot, model, 3, deliveri, today, toronto, tomo...
# 18           -1.0  [gfischer, tri, adjust, tire, pressur, ask, te...
# 19           -4.0                                       [hell, week]
# 20            0.0                               [uk, mid, 2019, rhd]
# 21            8.0                       [sound, like, fun, adventur]
# 22            2.0  [uk, take, aero, ins, standard, wheel, amp, lo...
# 23            9.0  [model, 3, second, best, world, model, sx, sti...
# 24            2.0  [filter, bacteria, virus, spore, pollen, amp, ...
# 25            0.0  [model, amp, x, also, acid, ga, filter, alkali...
# 26            0.0  [open, door, social, media, user, come, behind...
# 27            4.0  [cool, tesla, sx, hospit, oper, room, air, qua...
# 28            0.0                                                 []
# 29            0.0               [berlin, wurst, hat, meisten, curri]
# ...           ...                                                ...
# 3223          0.0  [tesla, model, x, final, here, stuff, didnt, a...
# 3224          4.0   [tesla, model, x, suv, final, wonder, wed, hope]
# 3225          0.0                                 [california, time]
# 3226          0.0  [model, x, launch, webcast, live, today, 8pm, ...
# 3227          2.0  [water, strong, evid, liquid, water, flow, pre...
# 3228          3.0  [great, discuss, solarbatteri, empow, rural, c...
# 3229          2.0               [china, show, commit, climat, chang]
# 3230         -2.0  [week, static, fire, first, stage, upgrad, fal...
# 3231          3.0  [dinner, old, belgian, ironmongeri, best, menu...
# 3232          6.0                                      [super, good]
# 3233          0.0                         [midnight, dinner, berlin]
# 3234          0.0  [casey, driven, 500, mile, tesla, model, 85d, ...
# 3235          0.0                                      [dragon, mar]
# 3236          1.0  [expend, mode, falcon, heavi, send, fulli, loa...
# 3237          5.0  [dragon, 2, design, land, surfac, liquid, soli...
# 3238          0.0  [research, propos, use, falcondragon, mar, sam...
# 3239          0.0  [snowpack, sierra, nevada, hit, 500year, low, ...
# 3240          2.0  [new, model, evolut, intellig, life, suggest, ...
# 3241          2.0                                            [thank]
# 3242          0.0               [btw, say, nuke, mar, layin, option]
# 3243          0.0  [crew, paner, unveil, interior, crew, dragon, ...
# 3244          0.0  [first, look, interior, crew, dragon, nextgene...
# 3245          0.0  [first, product, car, hand, sept, 29, fremont,...
# 3246          0.0                                          [definit]
# 3247          3.0  [lithium, deal, exclus, amp, mani, conting, pr...
# 3248          0.0         [35k, price, unveil, march, preorder, sta]
# 3249          0.0  [model, 3, smaller, lower, cost, sedan, sta, p...
# 3250          3.0  [option, model, x, 5k, due, greater, size, amp...
# 3251          0.0  [pad, 39a, futur, home, crew, launch, falcon, ...
# 3252          3.0       [test, drive, new, tesla, dealer, dan, love]
#
#       favorites  retweets                time
# 0           136        11 2018-06-01 08:29:40
# 1           141        11 2018-06-01 08:25:09
# 2           139         6 2018-06-01 08:23:54
# 3          1025        43 2018-06-01 02:47:53
# 4         13507      1408 2018-06-01 02:45:30
# 5          3436       396 2018-06-01 02:41:22
# 6             0      1208 2018-06-01 02:14:23
# 7         36499      5062 2018-06-01 02:13:19
# 8         34973      3655 2018-06-01 01:14:52
# 9          1073       234 2018-05-31 20:24:45
# 10         2152       280 2018-05-31 20:18:58
# 11         1612       118 2018-05-31 19:39:57
# 12         1048        66 2018-05-31 19:37:32
# 13         9100       982 2018-05-31 19:29:57
# 14        45496      4012 2018-05-31 17:48:55
# 15         5116       448 2018-05-31 17:17:06
# 16        42966      2557 2018-05-31 14:41:20
# 17            0       860 2018-05-31 07:53:01
# 18          437        10 2018-05-31 05:18:53
# 19       157447     26698 2018-05-31 04:18:00
# 20          136        11 2018-06-01 08:29:40
# 21          141        11 2018-06-01 08:25:09
# 22          139         6 2018-06-01 08:23:54
# 23         1025        43 2018-06-01 02:47:53
# 24        13507      1408 2018-06-01 02:45:30
# 25         3436       396 2018-06-01 02:41:22
# 26            0      1208 2018-06-01 02:14:23
# 27        36499      5062 2018-06-01 02:13:19
# 28        34973      3655 2018-06-01 01:14:52
# 29         1073       234 2018-05-31 20:24:45
# ...         ...       ...                 ...
# 3223          0       566 2015-09-30 07:46:33
# 3224          0      1394 2015-09-30 07:44:30
# 3225        719       178 2015-09-29 07:43:37
# 3226       5097      3838 2015-09-29 07:39:41
# 3227          0     42457 2015-09-28 16:12:34
# 3228       1973      1739 2015-09-27 01:02:35
# 3229          0       407 2015-09-26 05:38:34
# 3230          0       642 2015-09-25 08:53:39
# 3231       1819       445 2015-09-25 00:44:09
# 3232        296        39 2015-09-23 22:31:41
# 3233       3409       855 2015-09-23 22:12:49
# 3234          0       317 2015-09-16 16:44:58
# 3235          0      2440 2015-09-15 01:41:54
# 3236       3290      1640 2015-09-14 21:35:57
# 3237       3300      1456 2015-09-14 21:26:37
# 3238       2071      1298 2015-09-14 21:24:22
# 3239          0      2104 2015-09-14 16:13:49
# 3240       2360      1283 2015-09-13 07:22:13
# 3241        861       136 2015-09-12 20:46:26
# 3242       7097      4185 2015-09-12 19:07:49
# 3243          0      1416 2015-09-11 00:24:33
# 3244          0      1325 2015-09-11 00:24:27
# 3245       1736       697 2015-09-02 20:59:53
# 3246         79        12 2015-09-02 20:57:45
# 3247        100        51 2015-09-02 20:39:18
# 3248       3814      2566 2015-09-02 20:25:26
# 3249       4899      4030 2015-09-02 20:22:20
# 3250       1620       701 2015-09-02 20:17:47
# 3251          0      1055 2015-09-02 06:30:41
# 3252          0      1094 2015-09-02 02:24:26
#
# [3253 rows x 5 columns]

# %%
tesla.to_csv('tesla.csv', index=False)

# %%
# Out:
#      afinn score                                            content  \
# 0            0.0                                   [finder, keeper]
# 1            0.0                                          [pravduh]
# 2            0.0                                               [hi]
# 3            0.0  [lot, model, 3, deliveri, today, toronto, tomo...
# 4           -1.0  [gfischer, tri, adjust, tire, pressur, ask, te...
# 8            2.0                       [your, welcom, come, regard]
# 9            0.0  [consum, repo, test, model, 3, found, issu, br...
# 10          -3.0  [tesla, alway, refut, aicl, mislead, amp, poin...
# 11           4.0  [ride, comfo, amp, aeroroad, nois, alreadi, be...
# 12           0.0                                  [pivac, prob, 83]
# 45           7.0  [schiff, good, progress, realli, proud, design...
# 46           2.0                                     [schiff, peac]
# 47           3.0                      [love, space, cowboy, esthet]
# 48           0.0                                                 []
# 49          -9.0  [risk, state, extrem, obviou, threat, violenc,...
# 74           4.0                    [your, welcom, appreci, letter]
# 75           3.0                                     [good, school]
# 76           5.0                              [thank, love, letter]
# 77           0.0                                                 []
# 78           1.0                                               [ye]
# 85           0.0                  [your, right, guy, buzzkil, them]
# 86           0.0                         [think, own, press, hello]
# 87          -2.0  [agre, media, held, account, tell, truth, mani...
# 88          -2.0   [your, miss, point, amp, live, bubbl, selfright]
# 89           2.0   [your, welcom, come, spacex, pleas, stop, assum]
# 101          0.0                                                 []
# 102          0.0                                       [that, mind]
# 103          0.0                     [sometim, even, think, person]
# 104          0.0                   [never, harder, parodi, account]
# 105          0.0            [nanotech, bs, imo, take, someth, noth]
# ..           ...                                                ...
# 428          2.0                                     [your, welcom]
# 429          0.0  [number, incorrect, tesla, fremont, 3rd, world...
# 430          0.0                                     [woke, frisbe]
# 431          0.0                                       [la, la, la]
# 432          0.0       [spacex, crew, dragon, ship, cape, 3, month]
# 433          0.0                                     [ar, technica]
# 435          0.0                                               [ok]
# 452          1.0  [mani, world, exist, outsid, solar, system, te...
# 458          0.0                                                 []
# 459          0.0                                                 []
# 464         -1.0  [alreadi, target, retro, burn, specif, point, ...
# 465          0.0                               [land, bounci, hous]
# 466          4.0  [yeah, great, creat, giant, object, retain, sh...
# 467          0.0  [spacex, tri, bring, rocket, upper, stage, bac...
# 468         -2.0                              [gonna, sound, crazi]
# 473         -3.0  [ye, excess, autom, tesla, mistak, precis, mis...
# 474         -9.0  [economist, use, bore, sma, wick, dri, wit, bo...
# 488         -1.0    [definit, take, correct, action, immedi, sorri]
# 497          4.0                               [cat, video, awesom]
# 508          1.0  [spacex, launch, experiment, space, junk, swee...
# 519          0.0                                                 []
# 520          0.0          [iitzbrendon, elon, univers, real, place]
# 521          0.0  [tomorrow, dragon, atop, fieri, rocket, deliv,...
# 522          1.0  [come, soon, tesla, merch, free, shot, store, ...
# 595          0.0  [learn, pour, flame, absinth, tower, glass, je...
# 650         -3.0  [deep, hole, bore, machin, sometim, touch, hon...
# 739          0.0  [falcon, heavi, launch, simul, almost, readi, ...
# 740         -1.0                            [custom, problem, solv]
# 861          2.0                                            [thank]
# 862          0.0  [stunt, said, yet, alreadi, affect, whole, aus...
#
#      favorites  retweets                time
# 0        21384      2067 2018-05-31 17:48:55
# 1         3477       324 2018-05-31 17:17:06
# 2        27503      1634 2018-05-31 14:41:20
# 3            0       768 2018-05-31 07:53:01
# 4          349         8 2018-05-31 05:18:53
# 8          552        21 2018-05-30 22:35:53
# 9            0       514 2018-05-30 22:35:14
# 10        6032       314 2018-05-30 22:34:02
# 11        3440       181 2018-05-30 19:09:23
# 12         394        15 2018-05-30 19:05:41
# 45        1112        67 2018-05-29 20:46:04
# 46         653        34 2018-05-29 20:42:03
# 47        2829       116 2018-05-29 18:51:38
# 48        1838        55 2018-05-29 18:44:43
# 49       61145      4737 2018-05-29 18:35:36
# 74         655        18 2018-05-28 23:34:58
# 75         487        15 2018-05-28 23:34:17
# 76       10022       622 2018-05-28 23:16:50
# 77         567        13 2018-05-28 23:08:58
# 78        1104        21 2018-05-28 23:06:03
# 85        1507        81 2018-05-27 02:14:20
# 86       16910      5619 2018-05-27 02:11:19
# 87           0     19414 2018-05-27 02:00:26
# 88       13518      2463 2018-05-27 01:59:46
# 89        6267       467 2018-05-27 01:51:14
# 101        950        19 2018-05-26 23:57:10
# 102        470        15 2018-05-26 23:37:55
# 103       4153       187 2018-05-26 23:32:14
# 104          0      3833 2018-05-26 23:30:32
# 105        746        39 2018-05-26 23:13:37
# ..         ...       ...                 ...
# 428      10890       661 2018-05-03 07:36:02
# 429        810        75 2018-05-02 22:56:23
# 430       5865       442 2018-05-02 21:14:51
# 431      54543      6613 2018-05-02 21:06:29
# 432       6351       575 2018-05-02 21:00:13
# 433       3278       120 2018-05-02 18:51:21
# 435       5454       253 2018-05-01 01:39:59
# 452          0      4715 2018-04-19 06:16:23
# 458       3284       233 2018-04-17 22:21:40
# 459       5270       504 2018-04-17 21:58:10
# 464       1360       100 2018-04-16 04:06:48
# 465      74430      7060 2018-04-16 01:02:13
# 466       2829       218 2018-04-15 23:56:51
# 467     107561     15586 2018-04-15 23:04:58
# 468      81736     10693 2018-04-15 23:01:20
# 473      42085      8163 2018-04-13 19:54:52
# 474      19267      2047 2018-04-13 08:11:31
# 488       1012        43 2018-04-08 07:09:34
# 497       1087        72 2018-04-07 20:31:05
# 508          0      2543 2018-04-03 11:14:56
# 519       2958       167 2018-04-01 23:35:21
# 520       3514       826 2018-04-01 23:20:17
# 521          0      2596 2018-04-01 23:13:47
# 522       7603       338 2018-04-01 22:14:22
# 595      15865      1073 2018-03-19 18:09:26
# 650      39444      3240 2018-03-03 22:42:54
# 739      66301      7445 2018-02-03 21:34:32
# 740      97095     14482 2018-02-03 03:40:11
# 861      88663     11124 2017-12-19 19:08:36
# 862          0      3673 2017-12-19 19:06:22
#
# [155 rows x 5 columns]
